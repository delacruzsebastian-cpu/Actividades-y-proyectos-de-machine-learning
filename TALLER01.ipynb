# %% [markdown]
# <a href="https://colab.research.google.com/github/delacruzsebastian-cpu/IA/blob/main/TALLER01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TALLER 1 SEBASTIAN DE LA CRUZ

# %% [markdown]
# #Primer punto Distribuciones discretas.

# %% [markdown]
# **Para todas las simulaciones:**

# %%
import numpy  
import scipy 
import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# **1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:**

# %%
N=10000
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros

# %% [markdown]
# **2.Grafique los números aleatorios,
# 3.Ordene de menor a mayor y grafique,
# 4.Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.**

# %% [markdown]
# **- bernoulli con cierto p entre 0 y 1**

# %%
m=300

p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
bern = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html

# %% [markdown]
# *graficas para bernoulli*

# %%
plt.plot(bern)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
bern.sort()
plt.plot(bern)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(bern, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=bern.mean()
varest=bern.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli ")
print("con p=",p,"son u_est=",avg,"var_est",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli
# con p= 0.3 son u_est= 0.2983 var_est 0.20931711

# %% [markdown]
# **- Binomial con n = 10 y p = 0.5**

# %%
m=11

n,p =10, 0.5

from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
bina = binom.rvs(n, p, size=N)

# %% [markdown]
# *graficas binomial*

# %%
plt.plot(bina)
plt.title(str(N)+" puntos distribuidos binomial con p="+str(p)+"y n="+str(n))
plt.show()

# %%
bina.sort()
plt.plot(bina)
plt.title(str(N)+" puntos distribuidos binomial ordenados con p="+str(p)+"y n="+str(n))
plt.show()

# %%
plt.hist(bina, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p)+"y n="+str(n))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=bina.mean()
varest=bina.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p, "y n=",n,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial ")
print("con p=",p,"son u_est=",avg,"var_est",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 y n= 10 son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial
# con p= 0.5 son u_est= 4.9713 var_est 2.4862763100000005

# %% [markdown]
# **- Geométrica con cierto p entre 0 y 1**

# %%
p = 0.3
m=15

from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
geo = geom.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(geo)
plt.title(str(N)+" puntos distribuidos geometrica con p="+str(p))
plt.show()

# %%
geo.sort()
plt.plot(geo)
plt.title(str(N)+" puntos distribuidos geometrica ordenados con p="+str(p))
plt.show()

# %%
plt.hist(geo, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometrica con p="+str(p))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=geo.mean()
varest=geo.var()
print("Los valores teoricos de la media y varianza para la geometrica con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial")
print("con p=",p,"son u_est=",avg,"var_est",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la geometrica con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la binomial
# con p= 0.3 son u_est= 3.3302 var_est 7.73136796

# %% [markdown]
# **- Poisson con cierto Lamnda L**

# %%
L = 5

m=30

from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')
pois = poisson.rvs(L, size=N)
plt.plot(pois)
plt.title(str(N)+" puntos distribuidos poisson con lambda="+str(L))
plt.show()

# %%
pois.sort()
plt.plot(pois)
plt.title(str(N)+" puntos distribuidos poisson ordenados con lambda="+str(L))
plt.show()

# %%
plt.hist(pois, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos poisson con lambda="+str(L))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=geo.mean()
varest=geo.var()
print("Los valores teoricos de la media y varianza para la geometrica con lambda=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para poisson ")
print("con lambda=",L,"son u_est=",avg,"var_est",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la geometrica con lambda= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para poisson
# con lambda= 5 son u_est= 3.3302 var_est 7.73136796

# %% [markdown]
# **- Binomial negativa con parametro p después de r fallos**

# %%
r,p = 5,0.5

m=11

from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(r, p, moments='mvsk')
nbina = nbinom.rvs(r, p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(nbina)
plt.title(str(N)+" puntos distribuidos binomial negativa con p="+str(p)+"y r fallos="+str(r))
plt.show()

# %%
nbina.sort()
plt.plot(nbina)
plt.title(str(N)+" puntos distribuidos binomial negativa ordenados con p="+str(p)+"y r fallos="+str(r))
plt.show()

# %%
plt.hist(nbina, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial negativa con p="+str(p)+"y r fallos="+str(r))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=nbina.mean()
varest=nbina.var()
print("Los valores teoricos de la media y varianza para la binomial negativa con p=",p, "y r fallos=",r,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa ")
print("con p=",p,"y r fallos =",r,"son u_est=",avg,"var_est",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial negativa con p= 0.5 y r fallos= 5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa
# con p= 0.5 y r fallos = 5 son u_est= 4.9558 var_est 9.748046359999998

# %% [markdown]
# #Segundo punto Distribuciones contínuas.

# %% [markdown]
# **1.Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:**

# %%
#Para todas las simulaciones:
N=1000

numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %% [markdown]
# **2.Grafique los números aleatorios.
# 3.Ordene de menor a mayor y grafique.
# 4.Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.**

# %% [markdown]
# *Normal de media 5 y desviación estandar 0.5*

# %%
from scipy.stats import norm

u=5
std=0.5

m=20

mean, var, skew, kurt = norm.stats(moments='mvsk',loc=u,scale=std)
nor = norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(nor)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()

# %%
nor.sort()
plt.plot(nor)
plt.title(str(N)+" puntos distribuidos normales ordenados")
plt.show()

# %%
plt.hist(nor, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html
avg=nor.mean()
varest=nor.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son\n u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son
#  u_est= 4.971391002002103 var_est= 0.2653971302092896

# %% [markdown]
# *Uniforme entre 0 y 255*

# %%
from scipy.stats import uniform

a=-5
b=5
m=30

mean, var, skew, kurt = uniform.stats(a,b,moments='mvsk')
uni = uniform.rvs (a,b, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(uni)
plt.title(str(N)+" puntos distribuidos uniformes con a="+str(a)+ " y b= "+str(b))
plt.show()

# %%
nor.sort()
plt.plot(uni)
plt.title(str(N)+" puntos distribuidos uniformes ordenados")
plt.show()

# %%
plt.hist(uni, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos uniformes con a="+str(a)+ " y b= "+str(b))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html
avg=uni.mean()
varest=uni.var()
print("Los valores teoricos de la media y varianza para la uniforme son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son\n u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la uniforme son u= -2.5 var= 2.083333333333333
# Los valores estimados en nuestro experimento de la media y varianza son
#  u_est= -2.415289418737892 var_est= 2.089367482281641

# %% [markdown]
# *T de Student con parametro K*

# %%
from scipy.stats import t
K=1.0
mean, var, skew, kurt = t.stats(moments='mvsk',df=K)
u=mean
std=var
r = t.rvs (df=K, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t con media="+str(u)+" y var="+str(std))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t ordenados con media="+str(u)+" y var="+str(std))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos t con u="+str(u)+ " y var= "+str(std))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para t son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son\n u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para t son u= inf var= nan
# Los valores estimados en nuestro experimento de la media y varianza son
#  u_est= 0.9383748520016727 var_est= 861.7865004628236

# %% [markdown]
# *Exponencial con Lamnda L*

# %%
L=0.3

from scipy.stats import expon

mean, var, skew, kurt = expon.stats(L, moments='mvsk')
u=mean
std=var
ex = expon.rvs (L, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(ex)
plt.title(str(N)+" puntos distribuidos exponencial con media="+str(u)+" y var="+str(std))
plt.show()

# %%
r.sort()
plt.plot(ex)
plt.title(str(N)+" puntos distribuidos exponencial ordenados con media="+str(u)+" y var="+str(std))
plt.show()

# %%
plt.hist(ex, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencial con u="+str(u)+ " y var= "+str(std))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html
avg=ex.mean()
varest=ex.var()
print("Los valores teoricos de la media y varianza para exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son\n u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para exponencial son u= 1.3 var= 1.0
# Los valores estimados en nuestro experimento de la media y varianza son
#  u_est= 1.2918070167577704 var_est= 1.0152029344413598

# %% [markdown]
# *Chi cuadrada con K grados de libertad*

# %%
K=3.0

from scipy.stats import chi2

mean, var, skew, kurt = chi2.stats(moments='mvsk',df=K)
u=mean
std=var
chic = chi2.rvs (df=K, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(chic)
plt.title(str(N)+" puntos distribuidos chi cuadrada con "+str(K)+"grados de libertad")
plt.show()

# %%
r.sort()
plt.plot(chic)
plt.title(str(N)+" puntos distribuidos chi cuadrada ordenados con "+str(K)+"grados de libertad")
plt.show()

# %%
plt.hist(chic, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos chi cuadrada con "+str(K)+"grados de libertad")
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para chi cuadrada son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son ")
print("u_est=avg","var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para chi cuadrada son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son
# u_est=avg var_est= 861.7865004628236

# %% [markdown]
# *Gamma con parametros k y theta t*

# %%
k,t=2.54,0.43

from scipy.stats import gamma

mean, var, skew, kurt = gamma.stats(k,t,moments='mvsk')
u=mean
std=var
gam = gamma.rvs (k,t, size=N)
plt.plot(gam)
plt.title(str(N)+" puntos distribuidos gamma con media="+str(u)+" y var="+str(std))
plt.show()

# %%
gam.sort()
plt.plot(gam)
plt.title(str(N)+" puntos distribuidos gamma ordenados con media="+str(u)+" y var="+str(std))
plt.show()

# %%
plt.hist(gam, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos gamma con u="+str(u)+ " y var= "+str(std))
plt.show()

# %%
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son\n u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para gamma son u= 2.97 var= 2.54
# Los valores estimados en nuestro experimento de la media y varianza son
#  u_est= 0.9383748520016727 var_est= 861.7865004628236

# %% [markdown]
# # TERCER PUNTO
